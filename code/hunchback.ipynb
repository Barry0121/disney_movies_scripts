# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import os

# %%
fp = os.path.join('..\scripts', 'aladdin.txt')

# os.listdir('scripts')
chars = []
words = []
scene_setup = []
scene = False
new_char = True

def get_scene_setup(string):
    '''
    get scence setup
    '''
    s = string
    scene_setup = s[s.find("("):s.find(")")+1]
    return scene_setup
def remove_scene_setup(string):
    '''
    get scence setup
    '''
    s = string
    scene_setup = s[s.find("("):s.find(")")+1]
    s = string.replace(scene_setup, ' ')
    return s

line_nums = []
with open(fp, 'r', encoding='utf-8') as infile:
#     print(infile.readlines())
    for num_l, line in enumerate(infile):
        num_l += 1
#         print(line)

        s = line
#         get scene setup


        if not new_char:
            if ':' in line and '               ' not in line:
                pass
            else:
                words[-1] += line
        if ':' in line:
            if '               ' in line:
                words[-1] += line
                continue
            line_nums += [num_l]
            words += [line.split(':')[1]]
            chars += [line.split(':')[0]]

            new_char = False

df = pd.DataFrame()
chars_words = np.array(list(zip(chars, words,line_nums)))
draft = pd.DataFrame(chars_words,columns = ['chars','lines','line_num'])
# 2) put lines into a df & store it
# 3)
draft['scene_setup'] = draft.lines.apply(get_scene_setup)
draft['mod_lines'] = draft.lines.apply(remove_scene_setup)
draft
# Out:
#             chars                                              lines line_num  \
# 0         ALADDIN    THE COMPLETE SCRIPT\nCOMPILED BY BEN SCRIPPS...        1
# 1         PEDDLER      Oh I come from a land\n    From a faraway ...        5
# 2           JAFAR                                  You...are late.\n       65
# 3          GAZEEM             A thousand apologies, O patient one.\n       66
# 4           JAFAR                               You have it, then?\n       67
# ..            ...                                                ...      ...
# 693       ALADDIN                                A whole new world\n     2628
# 694       JASMINE                                 A whole new life\n     2629
# 695          BOTH      (with off-camera chorus)    For you and me!\n     2630
# 696  MEN'S CHORUS     A whole new world!\n\n(They fly off into th...     2631
# 697         GENIE    Made ya look!\n\n(Drops the film back to nor...     2638
#
#                                            scene_setup  \
# 0                              (Portions Copyright (c)
# 1       (Camera zooms in hitting\n    peddler in face)
# 2
# 3
# 4
# ..                                                 ...
# 693
# 694
# 695                           (with off-camera chorus)
# 696  (They fly off into the moonlight, and after th...
# 697  (Drops the film back to normal, with the norma...
#
#                                              mod_lines
# 0      THE COMPLETE SCRIPT\nCOMPILED BY BEN SCRIPPS...
# 1        Oh I come from a land\n    From a faraway ...
# 2                    Y o u . . . a r e   l a t e . \n
# 3     A   t h o u s a n d   a p o l o g i e s ,   O...
# 4              Y o u   h a v e   i t ,   t h e n ? \n
# ..                                                 ...
# 693              A   w h o l e   n e w   w o r l d \n
# 694                   A   w h o l e   n e w   l i f...
# 695                                  For you and me!\n
# 696                        A whole new world!\n\n \n\n
# 697                                 Made ya look!\n\n
#
# [698 rows x 5 columns]

# %%
fp = os.path.join('..\scripts', 'beauty_and_the_beast.txt')

# os.listdir('scripts')
chars = []
words = []
scene_setup = []
scene = False
new_char = True

def get_scene_setup(string):
    '''
    get scence setup
    '''
    s = string
    scene_setup = s[s.find("("):s.find(")")+1]
    return scene_setup
def remove_scene_setup(string):
    '''
    get scence setup
    '''
    s = string
    scene_setup = s[s.find("("):s.find(")")+1]
    s = string.replace(scene_setup, ' ')
    return s

line_nums = []
with open(fp, 'r', encoding='utf-8') as infile:
    for num_l, line in enumerate(infile):
        num_l += 1
        s = line
        if not new_char:
            if ':' in line and '               ' not in line:
                pass
            else:
                words[-1] += line
        if ':' in line:
            if '               ' in line:
                words[-1] += line
                continue
            line_nums += [num_l]
            words += [line.split(':')[1]]
            chars += [line.split(':')[0]]

            new_char = False

df = pd.DataFrame()

chars_words = np.array(list(zip(chars, words,line_nums)))
draft = pd.DataFrame(chars_words,columns = ['chars','lines','line_num'])
# 2) put lines into a df & store it
# 3)
draft['scene_setup'] = draft.lines.apply(get_scene_setup)
draft['mod_lines'] = draft.lines.apply(remove_scene_setup)
draft
# Out:
#            chars                                              lines line_num  \
# 0       NARRATOR       Once upon a time, in a faraway land, a yo...        7
# 1          BELLE          Little town, it's a quiet village\n   ...       36
# 2    TOWNSFOLK 1                                         Bonjour!\n       41
# 3    TOWNSFOLK 2                                         Bonjour!\n       42
# 4    TOWNSFOLK 3                                         Bonjour!\n       43
# ..           ...                                                ...      ...
# 693      LUMIERE        En garde, you overgrown pocket watch! (H...     1791
# 694         CHIP           Are they gonna live happily ever afte...     1796
# 695   MRS. POTTS                   Of course, my dear. Of course.\n     1797
# 696         CHIP           (Looks happy for a moment, then puzzl...     1798
# 697       CHORUS         Certain as the sun\n              Risin...     1806
#
#                                            scene_setup  \
# 0    (We have seen a progression of stained glass w...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 693  (He takes off his glove and\n              sla...
# 694
# 695
# 696          (Looks happy for a moment, then puzzled.)
# 697                  (Fade out into credits. The end.)
#
#                                              mod_lines
# 0         Once upon a time, in a faraway land, a yo...
# 1                     L i t t l e   t o w n ,   i t...
# 2                                  B o n j o u r ! \n
# 3                                  B o n j o u r ! \n
# 4                                  B o n j o u r ! \n
# ..                                                 ...
# 693          En garde, you overgrown pocket watch!  \n
# 694                     A r e   t h e y   g o n n a...
# 695         O f   c o u r s e ,   m y   d e a r .  ...
# 696             Do I still have to\n              s...
# 697         Certain as the sun\n              Risin...
#
# [698 rows x 5 columns]

# %%
print('\t\thello')
'               ' in'               of witchcraft.  The sentence'
# Out:
# 		hello
# True

# %%
import re
s = "this is a ki_te message"
s[s.find("(")+1:s.find(")")]
s.find(")")
# Out:
# -1

# %%
fp = os.path.join('..\scripts', 'the_hunchback_of_notre_dame.txt')

# os.listdir('scripts')
chars = []
words = []
scene_setup = []
scene = False
new_char = True

def get_scene_setup(string):
    '''
    get scence setup
    '''
    s = string
    scene_setup = s[s.find("("):s.find(")")+1]
    return scene_setup
def remove_scene_setup(string):
    '''
    get scence setup
    '''
    s = string
    scene_setup = s[s.find("("):s.find(")")+1]
    s = string.replace(scene_setup, ' ')
    return s
#     if '(' in line:  
#         if s.find(")") == -1:
#             scene_setup += [s[s.find("("):]]
#             scene = True
#             continue
#         else:
#             scene_setup += [s[s.find("("):s.find(")")+1]]                
#     if scene:
#         if ')' in line:
#             scene_setup[-1] += s[:s.find(")")+1]
#             scene = False
#         else:
#             scene_setup[-1] += s[:]
line_nums = []
with open(fp, 'r', encoding='utf-8') as infile:

    for num_l, line in enumerate(infile):
        num_l += 1
#         print(line)

        s = line
#         get scene setup


        if not new_char:
            if ':' in line and '               ' not in line:
                pass
            else:
                words[-1] += line
        if ':' in line:
#             The problem with this is that its only applied for
#             scripts with in-line lines with characters
            if '               ' in line:
                words[-1] += line
                continue
            line_nums += [num_l]
            words += [line.split(':')[1]]
            chars += [line.split(':')[0]]

            new_char = False

df = pd.DataFrame()
# np.array(chars).shape
# np.array(words).shape
chars_words = np.array(list(zip(chars, words,line_nums)))
draft = pd.DataFrame(chars_words,columns = ['chars','lines','line_num'])
# 2) put lines into a df & store it
# 3)
draft['scene_setup'] = draft.lines.apply(get_scene_setup)
draft['mod_lines'] = draft.lines.apply(remove_scene_setup)
draft
# Out:
#             chars                                              lines line_num  \
# 0            NOTE    The following script is Copyright (c) 1996 T...        8
# 1    EDITION NOTE   In the following script, any words in capital...       13
# 2          Clopin          MORNING IN PARIS, THE CITY AWAKES\n   ...       27
# 3          Puppet                                  They don't?!?\n\n       41
# 4          Clopin          No, silly boy.  Up there, high, high i...       43
# ..            ...                                                ...      ...
# 698     Esmeralda       Quasimodo!  Quasi!\n\n(He slips loose and...     2638
# 699     Esmeralda       No!!!\n\n(He falls right along the buildi...     2642
# 700        Clopin          Three cheers for Quasimodo!!\n\n(The c...     2658
# 701        Clopin          SO...\n               HERE IS A RIDDLE...     2662
# 702       Laverne         Don't you ever migrate?\n\n(We continue...     2675
#
#                                            scene_setup  \
# 0                                                  (c)
# 1                 (even lines *spoken*\nwithin a song)
# 2
# 3
# 4
# ..                                                 ...
# 698               (He slips loose and begins to fall.)
# 699  (He falls right along the building, close enou...
# 700             (The crowd breaks into loud cheering.)
# 701  (A long pullout, as we see the crowd following...
# 702  (We continue to pull out, until the entire cit...
#
#                                              mod_lines
# 0      The following script is Copyright   1996 The...
# 1     In the following script, any words in capital...
# 2                     M O R N I N G   I N   P A R I...
# 3                     T h e y   d o n ' t ? ! ? \n \n
# 4                     N o ,   s i l l y   b o y .  ...
# ..                                                 ...
# 698                        Quasimodo!  Quasi!\n\n \n\n
# 699                                     No!!!\n\n \n\n
# 700              Three cheers for Quasimodo!!\n\n \n\n
# 701          SO...\n               HERE IS A RIDDLE...
# 702                       Don't you ever migrate?\n\n
#
# [703 rows x 5 columns]

# %%
# path = "..\\scripts\\sleeping_beauty.txt"
# fp = os.path.join('..\scripts', 'the_hunchback_of_notre_dame.txt')
# # with open(fp, 'r', encoding='utf-8') as infile:
# #     print(infile.readlines())
# file = open(fp, 'r')
# script = file.readlines()
# file.close()
# start, end = 25, 1156


# line_count = 0 # number of lines total 
# characters = set() # all the characters
# lines = [] # character with their lines, index are the line numbers

# #TODO: get rid of '[...]', stage setup instructions, from the lines 
# def remove_setup(string): 
#     stack = False
#     new_str = ""
#     for s in string:
#         if s=='(':
#             stack = True
#         elif s==')':
#             stack = False
#         else: 
#             if not stack:
#                 new_str += s
#     return new_str.strip()


# for i in range(start, end+1):
#     holder = script[i] # line that is being read
#     if ':' in holder:
#         character = holder[:-1]
#         characters.add(character) # record for unique characters
#         lines.append([character, ""])
#         line_count += 1
#     else:
#         if len(holder) != 0 and line_count != 0:
#             lines[line_count-1][1] += holder
# lines
# # lines = np.array(lines)
# # d = {'Char':lines[:,0]
# #      ,'line': lines[:,1]}
# # pd.DataFrame(d)
# lines

# %%
m = np.array(['asdsad'])
m[-1] += 'asdsadasd'
m
# Out:
# array(['asdsad'], dtype='<U6')

# %%
fp = os.path.join('..\scripts', 'the_rescuers_down_under.txt')

chars = []
words = []
scene_setup = []
scene = False
new_char = True

def get_scene_setup(string):
    '''
    get scence setup
    '''
    s = string
    scene_setup = s[s.find("["):s.find("]")+1]
    return scene_setup
def remove_scene_setup(string):
    '''
    get scence setup
    '''
    s = string
    scene_setup = s[s.find("["):s.find("]")+1]
    s = string.replace(scene_setup, ' ')
    return s

line_nums = []
with open(fp, 'r', encoding='utf-8') as infile:
#     print(infile.readlines())
    for num_l, line in enumerate(infile):
        num_l += 1
#         print(line)

        s = line
#         get scene setup


        if not new_char:
            if ':' in line and '               ' not in line:
                pass
            else:
                words[-1] += line
        if ':' in line:
            if '               ' in line:
                words[-1] += line
                continue
            line_nums += [num_l]
            words += [line.split(':')[1]]
            chars += [line.split(':')[0]]

            new_char = False

df = pd.DataFrame()
# np.array(chars).shape
# np.array(words).shape
chars_words = np.array(list(zip(chars, words,line_nums)))
draft = pd.DataFrame(chars_words,columns = ['chars','lines','line_num'])
# 2) put lines into a df & store it
# 3)
draft['scene_setup'] = draft.lines.apply(get_scene_setup)
draft['mod_lines'] = draft.lines.apply(remove_scene_setup)
draft
# Out:
#             chars                                              lines line_num  \
# 0    Release date                                November 16, 1990\n        4
# 1    Running time   74 minutes\n\nTHE CHARACTERS\nMajor character...        5
# 2         opening   The camera slowly zooms through a variety of ...       29
# 3           scene   inside Cody's room. The camera pans around to...       30
# 4           scene   Cody sneaks past his mother who is in the kit...       31
# ..            ...                                                ...      ...
# 453        Bianca  \n[shocked] Bernard! Of COURSE, I will! [hugs ...      899
# 454          Jake  \nWell done mate. [Jake gives Bernard the thum...      901
# 455          Cody  \nCome on Marahute, let's all go home. [Marhut...      903
# 456         scene             high on the cliff at Marahute's nest\n      905
# 457        Wilbur  \nHelp!!! Anybody!! Bernard!! Bianca!! Where a...      906
#
#                                            scene_setup  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 453                                          [shocked]
# 454           [Jake gives Bernard the thumbs up sign.]
# 455  [Marhute flies higher and the four of them cru...
# 456
# 457                                       [to himself]
#
#                                              mod_lines
# 0                N o v e m b e r   1 6 ,   1 9 9 0 \n
# 1       7 4   m i n u t e s \n \n T H E   C H A R A...
# 2       T h e   c a m e r a   s l o w l y   z o o m...
# 3       i n s i d e   C o d y ' s   r o o m .   T h...
# 4       C o d y   s n e a k s   p a s t   h i s   m...
# ..                                                 ...
# 453  \n  Bernard! Of COURSE, I will! [hugs Bernard.]\n
# 454                              \nWell done mate.  \n
# 455         \nCome on Marahute, let's all go home.  \n
# 456     h i g h   o n   t h e   c l i f f   a t   M...
# 457  \nHelp!!! Anybody!! Bernard!! Bianca!! Where a...
#
# [458 rows x 5 columns]
